# %%
#  Import dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd

# Link to driver and splinter browser
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# Link to Vintagraph site
base_url = 'https://vintagraph.com'
wpa_url = 'https://vintagraph.com/collections/wpa-posters'
poster_list = []

# Loop through Vintagraph pages
for x in range(1, 12):
    
    search = f"?page={x}" 
    browser_url = f"{wpa_url}{search}"
    browser.visit(browser_url)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    # Select poster items
    posters = soup.find_all('div', class_="product")
  
    # Loop through all posters on page
    for poster in posters:
        
        select_title = poster.find('a', class_='product__image')['title']
        poster_url_link = poster.find('a', class_='product__image')['href']
        poster_sale_url = f"{base_url}{poster_url_link}"
        
        poster_to_add = {'Poster Title': select_title, 'Poster Url': poster_sale_url}
        poster_list.append(poster_to_add)
        
# Convert to dataframe
vintagraph_posters = pd.DataFrame(poster_list) 
    
vintagraph_posters
# Out:
#                                           Poster Title  \
# 0                                Keep Your Teeth Clean
# 1      Wild Life: The National Parks Preserve All Life
# 2                            Zion National Park Poster
# 3                                    Yellowstone: 1938
# 4                      See America: Welcome to Montana
# 5                                Keep Clean WPA Poster
# 6                     See America WPA Poster (Cowboys)
# 7                    National Parks Preserve Wild Life
# 8                     See America poster (Blue Cavern)
# 9                                       Save Your Eyes
# 10                 City of New York Municipal Airports
# 11                   Grand Canyon National Park poster
# 12                               Eat Fruit: Be Healthy
# 13                                  Protect Your Hands
# 14                               Be Kind to Books Club
# 15                                      6 + 8 Penguins
# 16                         Visit the Zoo: Philadelphia
# 17                               To-day is another day
# 18                           Be Careful Near Machinery
# 19                             John Is Not Really Dull
# 20             Welcome to Montana National Park poster
# 21                                      Work With Care
# 22                                      Just a Scratch
# 23                       Work Pays America! Prosperity
# 24                                 Buckingham Fountain
# 25                            Work Promotes Confidence
# 26                              Help Your Neighborhood
# 27                              Milk For Summer Thirst
# 28                                  Visit the Aquarium
# 29                                  Work With Care Man
# ..                                                 ...
# 138                    Just One Long Step to Sea Cliff
# 139     Visit Newfoundland: Canada's Newest Playground
# 140                       A Book Mark Would Be Better!
# 141                                Don't Gum Up a Book
# 142                   Syphilis May Cause Heart Trouble
# 143                                      Find Syphilis
# 144                                   Evite Accidentes
# 145                                The Path of Flowers
# 146                                   Independence Day
# 147                              Card Party and Barter
# 148                                 Birds of the World
# 149                           Art Classes for Children
# 150                           A Road to Future Success
# 151                     Visit the Brookfield Zoo Panda
# 152                                 Canada for Fishing
# 153                      Canada Welcomes U.S. Citizens
# 154  Pueblos of the Southwest: National Parks & Mon...
# 155                       Keep Your Teeth Clean (Pink)
# 156                                 I Want a Policeman
# 157                   A Game Crop is a Community Asset
# 158                               Carnival of the Arts
# 159                                     Horse Eats Hat
# 160                                  Follow the Parade
# 161                       Will Rogers Field Dedication
# 162                                  Art & Mrs. Bottle
# 163                        Protection Against Syphilis
# 164                          The Job of Being a Parent
# 165                                   WPA Memorial Day
# 166                                 Free Band Concerts
